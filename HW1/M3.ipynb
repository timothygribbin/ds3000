# %%
import numpy as np
from numpy import array

M = array([[1, 3, 0], [0, 1, 1], [0, 0, 2]])
print(M)
# Out:
# [[1 3 0]
#  [0 1 1]
#  [0 0 2]]

# %%
tr_M = np.trace(M)
print(tr_M)
# Out:
# 4

# %%
diag_M = np.diag(M)
print(diag_M)
# Out:
# [1 1 2]
