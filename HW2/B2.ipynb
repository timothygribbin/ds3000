# %%
import sympy as sp

A = sp.Matrix([[2, 1, -1, 3], [4, -2, 1, 1], [-2, 1, 2, 4]])

A_rref = A.rref()

print(A_rref)
# Out:
# (Matrix([
# [1, 0, 0, 11/10],
# [0, 1, 0,  13/5],
# [0, 0, 1,   9/5]]), (0, 1, 2))
