# %%
import sympy as sp

A = sp.Matrix([[1, -2, 3, 4], [2, -4,  6, 8], [-1, 2, -3, -4]])

A_rref = A.rref()

print(A_rref)
# Out:
# (Matrix([
# [1, -2, 3, 4],
# [0,  0, 0, 0],
# [0,  0, 0, 0]]), (0,))
